# %%
import pandas as pd

# %%
df = pd.read_csv("../data/data.csv")
df.head()
# Out:
#    id          recipe_name type_of_dish main_ingredient  cuisine  \
# 0   0  Spaghetti Bolognese  Main Course            Beef  Italian
# 1   1        Chicken Curry  Main Course         Chicken   Indian
# 2   2         Caesar Salad    Appetizer         Lettuce  Western
# 3   3       Chocolate Cake      Dessert       Chocolate  Western
# 4   4       Grilled Salmon  Main Course          Salmon  Western
#
#   cooking_method   prep_time   cook_time  \
# 0      Simmering  10 minutes  40 minutes
# 1       Sautéing  15 minutes  30 minutes
# 2        Tossing  10 minutes   0 minutes
# 3         Baking  20 minutes  35 minutes
# 4       Grilling   5 minutes  10 minutes
#
#                                         instructions
# 0  Heat olive oil in a large pan over medium heat...
# 1  Heat oil in a large pan over medium heat. Add ...
# 2  In a large bowl, toss chopped romaine lettuce ...
# 3  Preheat oven to 180°C (350°F). In a large bowl...
# 4  Preheat grill to high heat. Rub salmon fillets...

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/minsearch/main/minsearch.py

# %%
df.columns
# Out:
# Index(['id', 'recipe_name', 'type_of_dish', 'main_ingredient', 'cuisine',
#        'cooking_method', 'prep_time', 'cook_time', 'instructions'],
#       dtype='object')

# %% [markdown]
# ### Ingestion

# %%
documents = df.to_dict(orient="records")
documents
# Out:
# [{'id': 0,
#   'recipe_name': 'Spaghetti Bolognese',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Italian',
#   'cooking_method': 'Simmering',
#   'prep_time': '10 minutes',
#   'cook_time': '40 minutes',
#   'instructions': 'Heat olive oil in a large pan over medium heat. Add finely chopped onions, carrots, and celery. Cook for 5-7 minutes until softened. Add minced beef and cook until browned. Pour in canned tomatoes, beef broth, and Italian herbs. Simmer uncovered for 30-40 minutes. Stir occasionally and season with salt and pepper. Serve over cooked spaghetti and garnish with fresh basil.'},
#  {'id': 1,
#   'recipe_name': 'Chicken Curry',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Indian',
#   'cooking_method': 'Sautéing',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Heat oil in a large pan over medium heat. Add finely chopped onions and sauté until golden brown. Stir in minced garlic, ginger, and spices (turmeric, cumin, coriander). Add chicken pieces and cook until browned on all sides. Pour in coconut milk and canned tomatoes. Simmer for 25-30 minutes until the chicken is fully cooked. Stir occasionally and adjust seasoning. Serve with steamed rice and naan bread.'},
#  {'id': 2,
#   'recipe_name': 'Caesar Salad',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Lettuce',
#   'cuisine': 'Western',
#   'cooking_method': 'Tossing',
#   'prep_time': '10 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'In a large bowl, toss chopped romaine lettuce with Caesar dressing. Add croutons and freshly grated Parmesan cheese. For extra protein, top with grilled chicken breast slices. Toss until well combined. Serve immediately with lemon wedges on the side.'},
#  {'id': 3,
#   'recipe_name': 'Chocolate Cake',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Chocolate',
#   'cuisine': 'Western',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '35 minutes',
#   'instructions': 'Preheat oven to 180°C (350°F). In a large bowl, whisk together flour, sugar, cocoa powder, baking powder, and salt. In another bowl, mix eggs, melted butter, and vanilla extract. Combine the wet and dry ingredients, and stir in milk until smooth. Pour batter into a greased baking pan and bake for 35-40 minutes, or until a toothpick inserted comes out clean. Let cool before serving.'},
#  {'id': 4,
#   'recipe_name': 'Grilled Salmon',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Salmon',
#   'cuisine': 'Western',
#   'cooking_method': 'Grilling',
#   'prep_time': '5 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'Preheat grill to high heat. Rub salmon fillets with olive oil, salt, and pepper. Place salmon on the grill, skin-side down, and cook for 5-6 minutes per side. Baste with lemon juice and herbs while grilling. Remove from the grill when the flesh is flaky. Serve with grilled vegetables or a fresh green salad.'},
#  {'id': 5,
#   'recipe_name': 'Fried Rice',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Rice',
#   'cuisine': 'Chinese',
#   'cooking_method': 'Frying',
#   'prep_time': '15 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Heat oil in a large wok over high heat. Add chopped garlic, onions, and vegetables (carrots, peas, bell peppers). Stir-fry for 3-4 minutes. Push the vegetables to one side and scramble an egg on the other side of the wok. Stir in cooked rice, soy sauce, and a pinch of salt. Fry for another 5-6 minutes until everything is well combined and heated through. Garnish with green onions before serving.'},
#  {'id': 6,
#   'recipe_name': 'Beef Stew',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'French',
#   'cooking_method': 'Simmering',
#   'prep_time': '30 minutes',
#   'cook_time': '50 minutes',
#   'instructions': 'In a large pot, heat oil over medium heat. Add beef chunks and brown on all sides. Remove beef and set aside. In the same pot, sauté chopped onions, garlic, and carrots for 5 minutes. Return the beef to the pot and add beef broth, red wine, and bay leaves. Bring to a boil, then reduce heat and simmer for 1.5-2 hours, stirring occasionally. Season with salt, pepper, and fresh thyme. Serve with mashed potatoes or crusty bread.'},
#  {'id': 7,
#   'recipe_name': 'Pancakes',
#   'type_of_dish': 'Snack',
#   'main_ingredient': 'Eggs',
#   'cuisine': 'American',
#   'cooking_method': 'Frying',
#   'prep_time': '10 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'In a large bowl, mix flour, sugar, baking powder, and a pinch of salt. In another bowl, whisk eggs, milk, and melted butter. Combine the wet and dry ingredients, stirring until smooth. Heat a non-stick pan over medium heat and pour in a small amount of batter. Cook each pancake for 2-3 minutes per side, or until bubbles form on the surface and the edges are golden brown. Serve with syrup and fresh fruit.'},
#  {'id': 8,
#   'recipe_name': 'Tacos',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Mexican',
#   'cooking_method': 'Grilling',
#   'prep_time': '15 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Season ground beef with taco spices (cumin, chili powder, paprika). Heat oil in a pan over medium heat and cook the beef until browned. Warm corn tortillas on a dry skillet or grill. Fill each tortilla with cooked beef, fresh salsa, shredded lettuce, cheese, and guacamole. Garnish with cilantro and a squeeze of lime. Serve immediately.'},
#  {'id': 9,
#   'recipe_name': 'Sushi Rolls',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Fish',
#   'cuisine': 'Japanese',
#   'cooking_method': 'Rolling',
#   'prep_time': '10 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'Place a sheet of nori (seaweed) on a bamboo mat. Spread a thin layer of cooked sushi rice on the nori, leaving a small border. Place thin slices of fish, cucumber, and avocado in the center. Roll tightly using the bamboo mat, then slice into bite-sized pieces with a sharp knife. Serve with soy sauce, pickled ginger, and wasabi.'},
#  {'id': 10,
#   'recipe_name': 'Beef Stroganoff',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Russian',
#   'cooking_method': 'Sautéing',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Heat oil in a large pan over medium heat. Add beef strips and cook until browned. Remove beef and set aside. In the same pan, sauté onions and garlic until translucent. Add mushrooms and cook until tender. Stir in flour and cook for 1 minute. Gradually add beef broth and sour cream, stirring until smooth. Return beef to the pan and simmer until cooked through. Serve over egg noodles or rice.'},
#  {'id': 11,
#   'recipe_name': 'Chicken Alfredo',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Italian',
#   'cooking_method': 'Sautéing',
#   'prep_time': '15 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Cook pasta according to package instructions. In a large skillet, heat butter and sauté garlic until fragrant. Add chicken and cook until no longer pink. Stir in cream and Parmesan cheese, and cook until the sauce thickens. Toss in cooked pasta and season with salt and pepper. Garnish with parsley and serve.'},
#  {'id': 12,
#   'recipe_name': 'Greek Salad',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Tomato',
#   'cuisine': 'Greek',
#   'cooking_method': 'Tossing',
#   'prep_time': '10 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'In a large bowl, combine chopped tomatoes, cucumbers, red onions, and Kalamata olives. Add crumbled feta cheese and fresh oregano. Toss with olive oil and lemon juice. Season with salt and pepper to taste. Serve chilled or at room temperature.'},
#  {'id': 13,
#   'recipe_name': 'Vegetable Stir-Fry',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Vegetables',
#   'cuisine': 'Asian',
#   'cooking_method': 'Stir-Frying',
#   'prep_time': '10 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Heat oil in a wok or large pan over high heat. Add chopped garlic and ginger, then stir-fry for 1 minute. Add mixed vegetables (bell peppers, broccoli, carrots) and cook until just tender. Stir in soy sauce and a pinch of sugar. Cook for an additional 2 minutes. Serve with rice or noodles.'},
#  {'id': 14,
#   'recipe_name': 'Lasagna',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Italian',
#   'cooking_method': 'Baking',
#   'prep_time': '30 minutes',
#   'cook_time': '60 minutes',
#   'instructions': 'Preheat oven to 180°C (350°F). In a large skillet, cook ground beef with onions and garlic until browned. Stir in tomato sauce and herbs. In a separate bowl, mix ricotta cheese with egg and Parmesan. Spread a layer of meat sauce in a baking dish, followed by a layer of lasagna noodles, then a layer of cheese mixture. Repeat layers and top with mozzarella cheese. Bake for 45 minutes. Let cool before serving.'},
#  {'id': 15,
#   'recipe_name': 'Chicken Parmesan',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Italian',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Preheat oven to 200°C (400°F). Pound chicken breasts to an even thickness. Dredge in flour, dip in beaten egg, and coat with breadcrumbs. Fry in olive oil until golden brown. Place chicken in a baking dish, top with marinara sauce and mozzarella cheese. Bake for 20-25 minutes until chicken is cooked through and cheese is melted. Serve with spaghetti.'},
#  {'id': 16,
#   'recipe_name': 'Vegetable Soup',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Vegetables',
#   'cuisine': 'Western',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'In a large pot, heat olive oil and sauté onions, garlic, and celery until softened. Add chopped vegetables (carrots, potatoes, green beans) and vegetable broth. Bring to a boil, then reduce heat and simmer until vegetables are tender. Season with salt, pepper, and herbs. Serve hot with crusty bread.'},
#  {'id': 17,
#   'recipe_name': 'Beef Tacos',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Mexican',
#   'cooking_method': 'Grilling',
#   'prep_time': '10 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Season ground beef with taco seasoning and cook in a skillet until browned. Warm taco shells or tortillas. Fill each shell with beef, shredded lettuce, diced tomatoes, and cheese. Top with salsa and a squeeze of lime juice. Serve with a side of sour cream and guacamole.'},
#  {'id': 18,
#   'recipe_name': 'Quiche Lorraine',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Eggs',
#   'cuisine': 'French',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '40 minutes',
#   'instructions': 'Preheat oven to 180°C (350°F). Prepare pie crust and fit into a pie dish. In a bowl, whisk together eggs, cream, salt, and pepper. Stir in cooked bacon and grated cheese. Pour into pie crust and bake for 35-40 minutes until set and golden brown. Let cool slightly before serving.'},
#  {'id': 19,
#   'recipe_name': 'Buffalo Wings',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'American',
#   'cooking_method': 'Frying',
#   'prep_time': '15 minutes',
#   'cook_time': '25 minutes',
#   'instructions': 'Preheat oil in a deep fryer or large pot. Toss chicken wings in a mixture of flour and spices. Fry in batches until crispy and cooked through. In a separate bowl, mix hot sauce and melted butter. Toss fried wings in the sauce. Serve with celery sticks and blue cheese dressing.'},
#  {'id': 20,
#   'recipe_name': 'Chili Con Carne',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Mexican',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '45 minutes',
#   'instructions': 'In a large pot, cook ground beef with onions and garlic until browned. Add chopped bell peppers, tomatoes, and kidney beans. Stir in chili powder, cumin, and paprika. Simmer for 30-40 minutes until thickened. Season with salt and pepper. Serve with cornbread or over rice.'},
#  {'id': 21,
#   'recipe_name': 'Chicken Caesar Wrap',
#   'type_of_dish': 'Snack',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'American',
#   'cooking_method': 'Rolling',
#   'prep_time': '10 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'In a bowl, combine cooked chicken strips with Caesar dressing and Parmesan cheese. Place a tortilla on a flat surface and spread with a layer of Caesar dressing. Add the chicken mixture and some chopped romaine lettuce. Roll up tightly and cut in half. Serve immediately.'},
#  {'id': 22,
#   'recipe_name': 'Sweet and Sour Pork',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Pork',
#   'cuisine': 'Chinese',
#   'cooking_method': 'Stir-Frying',
#   'prep_time': '15 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Cut pork into bite-sized pieces and coat with cornstarch. Fry in hot oil until golden brown. Remove and set aside. In the same pan, sauté bell peppers, onions, and pineapple chunks. Stir in sweet and sour sauce and add the pork back in. Cook until sauce thickens. Serve with rice.'},
#  {'id': 23,
#   'recipe_name': 'Eggplant Parmesan',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Eggplant',
#   'cuisine': 'Italian',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '40 minutes',
#   'instructions': 'Preheat oven to 200°C (400°F). Slice eggplant and coat with flour, egg, and breadcrumbs. Fry until golden brown. In a baking dish, layer eggplant slices with marinara sauce and mozzarella cheese. Bake for 30-35 minutes until bubbly and golden. Let cool before serving.'},
#  {'id': 24,
#   'recipe_name': 'Chicken Fajitas',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Mexican',
#   'cooking_method': 'Grilling',
#   'prep_time': '15 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Slice chicken breasts and marinate in lime juice, oil, and fajita seasoning. Grill or cook in a skillet until cooked through. Slice bell peppers and onions, and cook in the same pan until tender. Serve with warm tortillas, salsa, guacamole, and sour cream.'},
#  {'id': 25,
#   'recipe_name': 'Garlic Mashed Potatoes',
#   'type_of_dish': 'Side Dish',
#   'main_ingredient': 'Potatoes',
#   'cuisine': 'American',
#   'cooking_method': 'Boiling',
#   'prep_time': '15 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Peel and cut potatoes into chunks. Boil in salted water until tender. Drain and return to the pot. Mash with butter, cream, and minced garlic. Season with salt and pepper. Serve warm with a sprinkle of chopped parsley.'},
#  {'id': 26,
#   'recipe_name': 'Tom Yum Soup',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Shrimp',
#   'cuisine': 'Thai',
#   'cooking_method': 'Simmering',
#   'prep_time': '10 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'In a pot, bring chicken broth to a boil. Add lemongrass, kaffir lime leaves, and galangal. Simmer for 5 minutes. Add shrimp and cook until pink. Stir in fish sauce, lime juice, and chili paste. Garnish with cilantro and serve hot.'},
#  {'id': 27,
#   'recipe_name': 'Beef Wellington',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'British',
#   'cooking_method': 'Baking',
#   'prep_time': '30 minutes',
#   'cook_time': '50 minutes',
#   'instructions': 'Preheat oven to 200°C (400°F). Sear beef fillet in a hot pan until browned. Let cool. Spread a layer of mushroom duxelles on a sheet of puff pastry. Place the beef on top and wrap in the pastry. Brush with egg wash and bake for 45 minutes. Let rest before slicing.'},
#  {'id': 28,
#   'recipe_name': 'Caprese Salad',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Tomato',
#   'cuisine': 'Italian',
#   'cooking_method': 'Tossing',
#   'prep_time': '10 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'Arrange slices of fresh tomato and mozzarella cheese on a plate. Top with fresh basil leaves. Drizzle with olive oil and balsamic vinegar. Season with salt and pepper. Serve immediately.'},
#  {'id': 29,
#   'recipe_name': 'Beef Bourguignon',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'French',
#   'cooking_method': 'Simmering',
#   'prep_time': '20 minutes',
#   'cook_time': '2 hours',
#   'instructions': 'Preheat oven to 160°C (325°F). In a large pot, brown beef chunks. Remove and set aside. In the same pot, cook onions, carrots, and garlic until softened. Add red wine, beef broth, and tomato paste. Return beef to the pot and add bay leaves. Cover and bake for 1.5-2 hours. Serve with potatoes or crusty bread.'},
#  {'id': 30,
#   'recipe_name': 'Pesto Pasta',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Pasta',
#   'cuisine': 'Italian',
#   'cooking_method': 'Boiling',
#   'prep_time': '10 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Cook pasta according to package instructions. In a food processor, blend basil, garlic, pine nuts, Parmesan cheese, and olive oil to make pesto. Toss cooked pasta with the pesto sauce. Serve with extra Parmesan cheese and pine nuts if desired.'},
#  {'id': 31,
#   'recipe_name': 'Shrimp Scampi',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Shrimp',
#   'cuisine': 'Italian',
#   'cooking_method': 'Sautéing',
#   'prep_time': '15 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Cook pasta according to package instructions. In a skillet, heat butter and olive oil. Add garlic and cook until fragrant. Add shrimp and cook until pink. Stir in lemon juice, white wine, and parsley. Toss with cooked pasta and serve with lemon wedges.'},
#  {'id': 32,
#   'recipe_name': 'Apple Pie',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Apple',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '30 minutes',
#   'cook_time': '60 minutes',
#   'instructions': 'Preheat oven to 220°C (425°F). Roll out pie crust and fit into a pie dish. Mix sliced apples with sugar, cinnamon, and flour. Pour into pie crust and top with another crust or lattice. Bake for 45-50 minutes until golden brown and apples are tender. Serve warm with vanilla ice cream.'},
#  {'id': 33,
#   'recipe_name': 'Chicken Pot Pie',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '40 minutes',
#   'instructions': 'Preheat oven to 200°C (400°F). Cook chicken and vegetables in a skillet with butter and flour. Stir in chicken broth and cream. Pour mixture into a pie dish and top with pie crust. Bake for 35-40 minutes until crust is golden and filling is bubbly.'},
#  {'id': 34,
#   'recipe_name': 'Falafel',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Chickpeas',
#   'cuisine': 'Middle Eastern',
#   'cooking_method': 'Frying',
#   'prep_time': '20 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'In a food processor, blend chickpeas with garlic, onions, cilantro, and spices. Form into balls and fry in hot oil until golden brown. Drain on paper towels. Serve with pita bread, hummus, and salad.'},
#  {'id': 35,
#   'recipe_name': 'Clam Chowder',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Clams',
#   'cuisine': 'American',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'In a pot, cook bacon until crispy. Remove and set aside. In the same pot, sauté onions, celery, and garlic until softened. Add clams, potatoes, and clam juice. Simmer until potatoes are tender. Stir in cream and cook until heated through. Garnish with bacon and parsley.'},
#  {'id': 36,
#   'recipe_name': 'Spinach Artichoke Dip',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Spinach',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '10 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Preheat oven to 180°C (350°F). Mix chopped spinach, artichoke hearts, cream cheese, sour cream, and Parmesan cheese in a bowl. Transfer to a baking dish and bake for 20 minutes until bubbly and golden. Serve with tortilla chips or bread.'},
#  {'id': 37,
#   'recipe_name': 'Jambalaya',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Rice',
#   'cuisine': 'Creole',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '45 minutes',
#   'instructions': 'In a large pot, cook sausage and chicken until browned. Remove and set aside. In the same pot, sauté onions, bell peppers, and celery. Add rice, tomatoes, and chicken broth. Stir in spices and return meat to the pot. Simmer until rice is cooked. Garnish with green onions.'},
#  {'id': 38,
#   'recipe_name': 'Stuffed Bell Peppers',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Bell Peppers',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Preheat oven to 180°C (350°F). Cut tops off bell peppers and remove seeds. In a bowl, mix cooked rice, ground beef, onions, and tomato sauce. Stuff peppers with the mixture and place in a baking dish. Bake for 30 minutes until peppers are tender. Serve hot.'},
#  {'id': 39,
#   'recipe_name': 'Cheese Fondue',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Cheese',
#   'cuisine': 'Swiss',
#   'cooking_method': 'Melting',
#   'prep_time': '10 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'In a fondue pot, heat white wine and add grated Swiss cheese in batches, stirring until melted. Add garlic and a splash of lemon juice. Serve with cubes of bread, vegetables, and fruit for dipping.'},
#  {'id': 40,
#   'recipe_name': 'Roasted Chicken',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'American',
#   'cooking_method': 'Roasting',
#   'prep_time': '20 minutes',
#   'cook_time': '60 minutes',
#   'instructions': 'Preheat oven to 180°C (350°F). Rub chicken with olive oil, salt, pepper, and herbs. Roast in a baking dish for 50-60 minutes until internal temperature reaches 75°C (165°F). Let rest before carving. Serve with roasted vegetables or potatoes.'},
#  {'id': 41,
#   'recipe_name': 'Beef Kebabs',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Middle Eastern',
#   'cooking_method': 'Grilling',
#   'prep_time': '15 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Cut beef into chunks and marinate in olive oil, lemon juice, garlic, and spices. Thread onto skewers and grill over high heat until cooked to your liking. Serve with rice or flatbread and a side of yogurt sauce.'},
#  {'id': 42,
#   'recipe_name': 'Pumpkin Soup',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Pumpkin',
#   'cuisine': 'American',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'In a large pot, sauté onions and garlic until soft. Add chopped pumpkin and vegetable broth. Simmer until pumpkin is tender. Puree with an immersion blender until smooth. Stir in cream and season with salt and pepper. Serve warm with crusty bread.'},
#  {'id': 43,
#   'recipe_name': 'Chocolate Chip Cookies',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Chocolate',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '15 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'Preheat oven to 180°C (350°F). Cream together butter, sugar, and brown sugar. Beat in eggs and vanilla extract. Gradually add flour, baking soda, and salt. Stir in chocolate chips. Drop spoonfuls of dough onto a baking sheet and bake for 10-12 minutes until edges are golden.'},
#  {'id': 44,
#   'recipe_name': 'Vegetarian Chili',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beans',
#   'cuisine': 'American',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'In a large pot, sauté onions, garlic, and bell peppers. Add canned tomatoes, kidney beans, black beans, and corn. Stir in chili powder, cumin, and paprika. Simmer for 30 minutes. Season with salt and pepper. Serve with cornbread or over rice.'},
#  {'id': 45,
#   'recipe_name': 'Beef Empanadas',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Latin American',
#   'cooking_method': 'Baking',
#   'prep_time': '30 minutes',
#   'cook_time': '25 minutes',
#   'instructions': 'Preheat oven to 200°C (400°F). Prepare dough and fill with a mixture of ground beef, onions, olives, and spices. Fold and seal edges, then bake for 20-25 minutes until golden brown. Serve with salsa or dipping sauce.'},
#  {'id': 46,
#   'recipe_name': 'Grilled Cheese Sandwich',
#   'type_of_dish': 'Snack',
#   'main_ingredient': 'Cheese',
#   'cuisine': 'American',
#   'cooking_method': 'Grilling',
#   'prep_time': '10 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'Butter slices of bread and place cheese between them. Grill in a skillet over medium heat until bread is golden and cheese is melted. Serve warm with tomato soup or salad.'},
#  {'id': 47,
#   'recipe_name': 'Banana Bread',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Banana',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '15 minutes',
#   'cook_time': '60 minutes',
#   'instructions': 'Preheat oven to 175°C (350°F). Mash ripe bananas and mix with flour, sugar, eggs, and baking powder. Pour into a greased loaf pan and bake for 50-60 minutes until a toothpick inserted comes out clean. Let cool before slicing.'},
#  {'id': 48,
#   'recipe_name': 'Chicken Quesadillas',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Mexican',
#   'cooking_method': 'Grilling',
#   'prep_time': '10 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'In a skillet, cook chicken with spices until fully cooked. Remove and shred. Place tortillas in a pan, add cheese, chicken, and any other desired fillings. Cook until cheese is melted and tortillas are golden brown. Cut into wedges and serve with salsa.'},
#  {'id': 49,
#   'recipe_name': 'Avocado Toast',
#   'type_of_dish': 'Snack',
#   'main_ingredient': 'Avocado',
#   'cuisine': 'American',
#   'cooking_method': 'Toasting',
#   'prep_time': '5 minutes',
#   'cook_time': '5 minutes',
#   'instructions': 'Toast slices of bread. Spread with mashed avocado and season with salt, pepper, and a drizzle of olive oil. Top with sliced tomatoes, radishes, or a poached egg if desired. Serve immediately.'},
#  {'id': 50,
#   'recipe_name': 'Ratatouille',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Vegetables',
#   'cuisine': 'French',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '50 minutes',
#   'instructions': 'Preheat oven to 180°C (350°F). Slice vegetables (eggplant, zucchini, bell peppers) thinly. Arrange in a baking dish, layering with tomato sauce and herbs. Bake for 45-50 minutes until vegetables are tender. Serve warm or at room temperature.'},
#  {'id': 51,
#   'recipe_name': 'Crab Cakes',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Crab',
#   'cuisine': 'American',
#   'cooking_method': 'Frying',
#   'prep_time': '20 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Mix crab meat with breadcrumbs, mayonnaise, egg, and seasonings. Form into cakes and fry in hot oil until golden brown. Serve with a side of tartar sauce or aioli.'},
#  {'id': 52,
#   'recipe_name': 'Chicken Shawarma',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Middle Eastern',
#   'cooking_method': 'Grilling',
#   'prep_time': '20 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Marinate chicken in a mixture of yogurt, lemon juice, and spices. Grill until cooked through. Serve in pita bread with lettuce, tomatoes, and tahini sauce.'},
#  {'id': 53,
#   'recipe_name': 'Macaroni and Cheese',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Pasta',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Cook macaroni according to package instructions. In a saucepan, make a cheese sauce with butter, flour, milk, and cheddar cheese. Mix with macaroni and pour into a baking dish. Top with more cheese and bake until bubbly and golden.'},
#  {'id': 54,
#   'recipe_name': 'Buffalo Chicken Dip',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '10 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Mix shredded chicken with cream cheese, hot sauce, ranch dressing, and cheese. Transfer to a baking dish and bake until bubbly. Serve with tortilla chips or celery sticks.'},
#  {'id': 55,
#   'recipe_name': 'Turkey Meatballs',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Turkey',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '15 minutes',
#   'cook_time': '25 minutes',
#   'instructions': 'Preheat oven to 180°C (350°F). Mix ground turkey with breadcrumbs, egg, and spices. Form into meatballs and bake for 20-25 minutes until cooked through. Serve with marinara sauce or as a meatball sub.'},
#  {'id': 56,
#   'recipe_name': 'Egg Drop Soup',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Eggs',
#   'cuisine': 'Chinese',
#   'cooking_method': 'Simmering',
#   'prep_time': '10 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'Heat chicken broth in a pot. Slowly stir in beaten eggs and cook until eggs form ribbons. Add soy sauce and garnish with sliced green onions. Serve hot.'},
#  {'id': 57,
#   'recipe_name': 'Pulled Pork Sandwiches',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Pork',
#   'cuisine': 'American',
#   'cooking_method': 'Slow Cooking',
#   'prep_time': '15 minutes',
#   'cook_time': '8 hours',
#   'instructions': 'Season pork shoulder and cook in a slow cooker with BBQ sauce for 8 hours. Shred the meat and serve on buns with coleslaw and additional BBQ sauce.'},
#  {'id': 58,
#   'recipe_name': 'Frittata',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Eggs',
#   'cuisine': 'Italian',
#   'cooking_method': 'Baking',
#   'prep_time': '10 minutes',
#   'cook_time': '25 minutes',
#   'instructions': 'Preheat oven to 180°C (350°F). Sauté vegetables in a skillet. Whisk eggs with cheese and pour over the vegetables. Transfer to the oven and bake until set. Serve warm or at room temperature.'},
#  {'id': 59,
#   'recipe_name': 'Crème Brûlée',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Cream',
#   'cuisine': 'French',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '45 minutes',
#   'instructions': 'Preheat oven to 150°C (300°F). Whisk egg yolks with sugar and vanilla, then stir in cream. Pour into ramekins and bake in a water bath for 30-35 minutes. Cool and chill. Caramelize sugar on top with a torch before serving.'},
#  {'id': 60,
#   'recipe_name': 'Teriyaki Chicken',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Japanese',
#   'cooking_method': 'Grilling',
#   'prep_time': '15 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Marinate chicken in teriyaki sauce and grill until cooked through. Serve with steamed rice and vegetables.'},
#  {'id': 62,
#   'recipe_name': 'Chicken Kiev',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Ukrainian',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '40 minutes',
#   'instructions': 'Preheat oven to 200°C (400°F). Flatten chicken breasts and spread with a mixture of butter, garlic, and herbs. Roll up and coat with breadcrumbs. Bake for 30-35 minutes until cooked through and golden brown.'},
#  {'id': 63,
#   'recipe_name': 'Spaghetti Carbonara',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Pasta',
#   'cuisine': 'Italian',
#   'cooking_method': 'Sautéing',
#   'prep_time': '10 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Cook pasta according to package instructions. In a skillet, cook pancetta or bacon until crispy. Whisk eggs and Parmesan cheese together. Toss cooked pasta with bacon and the egg mixture. Serve immediately with extra cheese and black pepper.'},
#  {'id': 64,
#   'recipe_name': 'Sweet Potato Fries',
#   'type_of_dish': 'Snack',
#   'main_ingredient': 'Sweet Potato',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '10 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Preheat oven to 220°C (425°F). Cut sweet potatoes into fries and toss with olive oil, salt, and paprika. Arrange on a baking sheet and bake for 25-30 minutes until crispy. Serve with dipping sauce.'},
#  {'id': 65,
#   'recipe_name': 'Pad Thai',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Noodles',
#   'cuisine': 'Thai',
#   'cooking_method': 'Stir-Frying',
#   'prep_time': '15 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Soak rice noodles in warm water. In a pan, stir-fry tofu or shrimp with garlic and vegetables. Add soaked noodles, tamarind paste, fish sauce, and sugar. Cook until well combined. Garnish with peanuts, cilantro, and lime wedges.'},
#  {'id': 66,
#   'recipe_name': 'Banana Split',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Banana',
#   'cuisine': 'American',
#   'cooking_method': 'Assembling',
#   'prep_time': '10 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'Slice bananas lengthwise and place in a dish. Top with scoops of vanilla, chocolate, and strawberry ice cream. Drizzle with chocolate and strawberry sauces. Add whipped cream, nuts, and cherries on top.'},
#  {'id': 67,
#   'recipe_name': 'Chicken Marsala',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Italian',
#   'cooking_method': 'Sautéing',
#   'prep_time': '15 minutes',
#   'cook_time': '25 minutes',
#   'instructions': 'Pound chicken breasts and dredge in flour. Sauté in a skillet with butter until golden brown. Remove chicken and set aside. In the same pan, cook mushrooms, then add Marsala wine and chicken broth. Return chicken to the pan and simmer until cooked through. Serve with pasta or mashed potatoes.'},
#  {'id': 68,
#   'recipe_name': 'Beef Stir-Fry',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Chinese',
#   'cooking_method': 'Stir-Frying',
#   'prep_time': '15 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Heat oil in a wok or skillet. Stir-fry beef strips with vegetables (bell peppers, broccoli, carrots). Add soy sauce and oyster sauce. Cook until beef is tender and vegetables are crisp. Serve with rice or noodles.'},
#  {'id': 69,
#   'recipe_name': 'Eggplant Rollatini',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Eggplant',
#   'cuisine': 'Italian',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '35 minutes',
#   'instructions': 'Preheat oven to 180°C (350°F). Slice eggplant and bake until tender. Spread with ricotta cheese mixture and roll up. Place in a baking dish, cover with marinara sauce, and top with mozzarella cheese. Bake for 30-35 minutes until bubbly.'},
#  {'id': 70,
#   'recipe_name': 'Pumpkin Pie',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Pumpkin',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '15 minutes',
#   'cook_time': '60 minutes',
#   'instructions': 'Preheat oven to 220°C (425°F). Mix pumpkin puree with eggs, cream, sugar, and spices. Pour into a pie crust and bake for 50-60 minutes until the filling is set. Serve with whipped cream.'},
#  {'id': 71,
#   'recipe_name': 'Chicken and Waffles',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'American',
#   'cooking_method': 'Frying',
#   'prep_time': '20 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Fry chicken pieces until crispy and cooked through. Prepare waffles according to package instructions or recipe. Serve chicken on top of waffles with maple syrup and butter.'},
#  {'id': 72,
#   'recipe_name': 'Shrimp Tacos',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Shrimp',
#   'cuisine': 'Mexican',
#   'cooking_method': 'Grilling',
#   'prep_time': '15 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Marinate shrimp in lime juice, chili powder, and garlic. Grill until cooked through. Serve in tortillas with cabbage slaw, avocado, and a squeeze of lime.'},
#  {'id': 73,
#   'recipe_name': 'Crepes',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Flour',
#   'cuisine': 'French',
#   'cooking_method': 'Grilling',
#   'prep_time': '10 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'In a bowl, mix flour, eggs, milk, and a pinch of salt. Heat a non-stick pan and pour in a small amount of batter, tilting to spread evenly. Cook until golden and flip. Fill with sweet or savory fillings and serve rolled or folded.'},
#  {'id': 74,
#   'recipe_name': 'Buffalo Chicken Wings',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'American',
#   'cooking_method': 'Frying',
#   'prep_time': '15 minutes',
#   'cook_time': '25 minutes',
#   'instructions': 'Fry chicken wings until crispy. Toss with a mixture of hot sauce and melted butter. Serve with celery sticks and ranch dressing.'},
#  {'id': 75,
#   'recipe_name': 'Chocolate Mousse',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Chocolate',
#   'cuisine': 'French',
#   'cooking_method': 'Chilling',
#   'prep_time': '15 minutes',
#   'cook_time': '2 hours',
#   'instructions': 'Melt chocolate and let cool. Whip cream until stiff peaks form. Fold chocolate into whipped cream. Spoon into serving dishes and chill for at least 2 hours. Garnish with chocolate shavings.'},
#  {'id': 76,
#   'recipe_name': 'Teriyaki Beef',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Japanese',
#   'cooking_method': 'Grilling',
#   'prep_time': '15 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Marinate beef strips in teriyaki sauce. Grill until desired doneness. Serve with steamed rice and vegetables.'},
#  {'id': 77,
#   'recipe_name': 'Greek Moussaka',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Eggplant',
#   'cuisine': 'Greek',
#   'cooking_method': 'Baking',
#   'prep_time': '30 minutes',
#   'cook_time': '60 minutes',
#   'instructions': 'Layer sliced eggplant with a mixture of ground beef, onions, and tomatoes in a baking dish. Top with a béchamel sauce and bake until golden and bubbly.'},
#  {'id': 78,
#   'recipe_name': 'Salmon Sushi',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Salmon',
#   'cuisine': 'Japanese',
#   'cooking_method': 'Rolling',
#   'prep_time': '20 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'Place a sheet of nori on a bamboo mat. Spread a thin layer of sushi rice, then add slices of salmon, cucumber, and avocado. Roll tightly and slice into pieces. Serve with soy sauce, pickled ginger, and wasabi.'},
#  {'id': 79,
#   'recipe_name': 'Cauliflower Rice',
#   'type_of_dish': 'Side Dish',
#   'main_ingredient': 'Cauliflower',
#   'cuisine': 'American',
#   'cooking_method': 'Sautéing',
#   'prep_time': '10 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'Grate cauliflower or pulse in a food processor until rice-sized. Sauté in a pan with oil until tender. Season with salt and pepper. Serve as a low-carb alternative to rice.'},
#  {'id': 80,
#   'recipe_name': 'French Onion Soup',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Onions',
#   'cuisine': 'French',
#   'cooking_method': 'Simmering',
#   'prep_time': '20 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Cook sliced onions in butter until caramelized. Add beef broth and simmer. Serve hot, topped with toasted baguette slices and melted Gruyère cheese.'},
#  {'id': 82,
#   'recipe_name': 'Chicken Enchiladas',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Mexican',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Fill tortillas with shredded chicken, cheese, and enchilada sauce. Roll up and place in a baking dish. Top with more sauce and cheese. Bake until bubbly.'},
#  {'id': 83,
#   'recipe_name': 'Carrot Cake',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Carrots',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '40 minutes',
#   'instructions': 'Mix grated carrots with flour, sugar, eggs, and spices. Bake in a greased pan. Cool and frost with cream cheese icing.'},
#  {'id': 84,
#   'recipe_name': 'Salmon Teriyaki',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Salmon',
#   'cuisine': 'Japanese',
#   'cooking_method': 'Grilling',
#   'prep_time': '15 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Marinate salmon in teriyaki sauce. Grill until cooked through. Serve with rice and vegetables.'},
#  {'id': 85,
#   'recipe_name': 'Quinoa Salad',
#   'type_of_dish': 'Side Dish',
#   'main_ingredient': 'Quinoa',
#   'cuisine': 'American',
#   'cooking_method': 'Tossing',
#   'prep_time': '15 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'Cook quinoa according to package instructions. Mix with diced vegetables, feta cheese, and a vinaigrette dressing. Serve chilled or at room temperature.'},
#  {'id': 86,
#   'recipe_name': 'Lemon Bars',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Lemon',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Preheat oven to 180°C (350°F). Prepare a crust with flour, butter, and sugar. Bake until golden. Mix lemon juice, eggs, and sugar for filling. Pour over crust and bake until set. Cool and cut into bars.'},
#  {'id': 87,
#   'recipe_name': 'Chicken Tikka Masala',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Indian',
#   'cooking_method': 'Simmering',
#   'prep_time': '20 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Marinate chicken in yogurt and spices. Cook in a sauce of tomatoes, cream, and spices until chicken is tender. Serve with rice or naan bread.'},
#  {'id': 88,
#   'recipe_name': 'Chili Con Carne',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Tex-Mex',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '45 minutes',
#   'instructions': 'Cook ground beef with onions, garlic, and spices. Add tomatoes, kidney beans, and beef broth. Simmer until flavors meld. Serve with cornbread or rice.'},
#  {'id': 89,
#   'recipe_name': 'Lentil Soup',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Lentils',
#   'cuisine': 'American',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Sauté onions, garlic, and carrots. Add lentils, vegetable broth, and spices. Simmer until lentils are tender. Serve hot with crusty bread.'},
#  {'id': 93,
#   'recipe_name': 'Pancakes',
#   'type_of_dish': 'Breakfast',
#   'main_ingredient': 'Flour',
#   'cuisine': 'American',
#   'cooking_method': 'Grilling',
#   'prep_time': '10 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'Mix flour, milk, eggs, and baking powder. Pour batter onto a hot griddle and cook until bubbles form. Flip and cook until golden brown. Serve with syrup and butter.'},
#  {'id': 94,
#   'recipe_name': 'Grilled Shrimp',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Shrimp',
#   'cuisine': 'American',
#   'cooking_method': 'Grilling',
#   'prep_time': '15 minutes',
#   'cook_time': '5 minutes',
#   'instructions': 'Marinate shrimp in olive oil, garlic, and lemon juice. Skewer and grill until pink and cooked through. Serve with a squeeze of lemon.'},
#  {'id': 95,
#   'recipe_name': 'Vegetable Stir-Fry',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Vegetables',
#   'cuisine': 'Chinese',
#   'cooking_method': 'Stir-Frying',
#   'prep_time': '10 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'Stir-fry a mix of vegetables (bell peppers, broccoli, carrots) in oil. Add soy sauce and garlic. Cook until vegetables are crisp-tender. Serve with rice or noodles.'},
#  {'id': 98,
#   'recipe_name': 'Tiramisu',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Coffee',
#   'cuisine': 'Italian',
#   'cooking_method': 'Chilling',
#   'prep_time': '30 minutes',
#   'cook_time': '4 hours',
#   'instructions': 'Mix mascarpone cheese with sugar and eggs. Layer with coffee-soaked ladyfingers. Chill for at least 4 hours. Dust with cocoa powder before serving.'},
#  {'id': 99,
#   'recipe_name': 'Fruit Salad',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Mixed Fruits',
#   'cuisine': 'American',
#   'cooking_method': 'Tossing',
#   'prep_time': '15 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'Mix a variety of fresh fruits (berries, melons, apples) in a bowl. Add a drizzle of honey or a squeeze of lemon juice if desired. Serve chilled.'},
#  {'id': 101,
#   'recipe_name': 'Sweet and Sour Chicken',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Chinese',
#   'cooking_method': 'Stir-Frying',
#   'prep_time': '15 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Stir-fry chicken pieces with vegetables. Add a sauce made from vinegar, sugar, ketchup, and soy sauce. Cook until chicken is coated and sauce is thickened.'},
#  {'id': 104,
#   'recipe_name': 'Beef Burritos',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Mexican',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Fill tortillas with seasoned beef, rice, beans, and cheese. Roll up and place in a baking dish. Top with more cheese and bake until bubbly.'},
#  {'id': 105,
#   'recipe_name': 'Lamb Chops',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Lamb',
#   'cuisine': 'Mediterranean',
#   'cooking_method': 'Grilling',
#   'prep_time': '15 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Season lamb chops with herbs and spices. Grill to desired doneness. Serve with a side of mint yogurt sauce and roasted vegetables.'},
#  {'id': 106,
#   'recipe_name': 'Chicken Noodle Soup',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'American',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Cook chicken in broth with carrots, celery, and noodles. Simmer until noodles are tender. Season with salt and pepper. Serve hot with crusty bread.'},
#  {'id': 107,
#   'recipe_name': 'Pumpkin Spice Latte',
#   'type_of_dish': 'Beverage',
#   'main_ingredient': 'Pumpkin',
#   'cuisine': 'American',
#   'cooking_method': 'Brewing',
#   'prep_time': '5 minutes',
#   'cook_time': '5 minutes',
#   'instructions': 'Brew espresso or strong coffee. Heat milk with pumpkin puree, cinnamon, nutmeg, and sugar. Froth milk and combine with coffee. Top with whipped cream and a sprinkle of pumpkin spice.'},
#  {'id': 108,
#   'recipe_name': 'Chicken Satay',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Thai',
#   'cooking_method': 'Grilling',
#   'prep_time': '20 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Marinate chicken skewers in a mixture of coconut milk, curry powder, and soy sauce. Grill until cooked through. Serve with peanut sauce for dipping.'},
#  {'id': 109,
#   'recipe_name': 'Roasted Brussels Sprouts',
#   'type_of_dish': 'Side Dish',
#   'main_ingredient': 'Brussels Sprouts',
#   'cuisine': 'American',
#   'cooking_method': 'Roasting',
#   'prep_time': '10 minutes',
#   'cook_time': '25 minutes',
#   'instructions': 'Preheat oven to 220°C (425°F). Toss Brussels sprouts with olive oil, salt, and pepper. Roast until crispy and browned. Serve as a side dish.'},
#  {'id': 110,
#   'recipe_name': 'Apple Crisp',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Apple',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '15 minutes',
#   'cook_time': '45 minutes',
#   'instructions': 'Preheat oven to 190°C (375°F). Mix sliced apples with sugar and cinnamon. Place in a baking dish and top with a crumbly mixture of flour, sugar, and butter. Bake until topping is golden and apples are tender.'},
#  {'id': 112,
#   'recipe_name': 'Cheesecake',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Cheese',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '15 minutes',
#   'cook_time': '60 minutes',
# ...
#   'prep_time': '10 minutes',
#   'cook_time': '8 hours',
#   'instructions': 'Cook chicken breasts with BBQ sauce in a slow cooker for 8 hours. Shred and serve on buns with coleslaw.'},
#  {'id': 190,
#   'recipe_name': 'Banana Bread',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Bananas',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '15 minutes',
#   'cook_time': '60 minutes',
#   'instructions': 'Mix mashed bananas with flour, sugar, eggs, and baking soda. Pour into a loaf pan and bake until a toothpick comes out clean.'},
#  {'id': 192,
#   'recipe_name': 'Beef and Broccoli Stir-Fry',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Chinese',
#   'cooking_method': 'Stir-Frying',
#   'prep_time': '15 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'Stir-fry sliced beef with broccoli and garlic in a hot pan. Add soy sauce and a bit of sugar. Serve with rice.'},
#  {'id': 196,
#   'recipe_name': 'Blueberry Muffins',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Blueberries',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '15 minutes',
#   'cook_time': '25 minutes',
#   'instructions': 'Mix flour, sugar, and baking powder with milk, eggs, and blueberries. Bake in muffin tins until golden brown.'},
#  {'id': 197,
#   'recipe_name': 'Peach Smoothie',
#   'type_of_dish': 'Snack',
#   'main_ingredient': 'Peach',
#   'cuisine': 'American',
#   'cooking_method': 'Blending',
#   'prep_time': '5 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'Blend fresh peaches with yogurt and a touch of honey until smooth. Serve chilled.'},
#  {'id': 199,
#   'recipe_name': 'Roast Chicken',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'American',
#   'cooking_method': 'Roasting',
#   'prep_time': '15 minutes',
#   'cook_time': '90 minutes',
#   'instructions': 'Season a whole chicken with herbs and spices. Roast in the oven until skin is crispy and chicken is cooked through. Serve with roasted vegetables.'},
#  {'id': 200,
#   'recipe_name': 'Apple Cider Donuts',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Apples',
#   'cuisine': 'American',
#   'cooking_method': 'Frying',
#   'prep_time': '20 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Mix flour, sugar, and spices with apple cider. Fry dough in small rounds and coat with cinnamon sugar. Serve warm.'},
#  {'id': 204,
#   'recipe_name': 'Fettuccine Alfredo',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Pasta',
#   'cuisine': 'Italian',
#   'cooking_method': 'Sautéing',
#   'prep_time': '15 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Cook fettuccine pasta and toss with a sauce made from butter, cream, and Parmesan cheese. Serve with a sprinkle of parsley.'},
#  {'id': 205,
#   'recipe_name': 'Tomato Basil Soup',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Tomatoes',
#   'cuisine': 'Italian',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Cook tomatoes with onions, garlic, and basil. Blend until smooth and stir in cream. Serve hot with a grilled cheese sandwich.'},
#  {'id': 206,
#   'recipe_name': 'Chicken Salad',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'American',
#   'cooking_method': 'Assembling',
#   'prep_time': '10 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'Mix shredded chicken with mayonnaise, celery, and herbs. Serve over lettuce or on a sandwich.'},
#  {'id': 210,
#   'recipe_name': 'Apple Cider Glazed Pork Chops',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Pork',
#   'cuisine': 'American',
#   'cooking_method': 'Grilling',
#   'prep_time': '10 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Grill pork chops and glaze with a mixture of apple cider, brown sugar, and mustard. Serve with roasted vegetables.'},
#  {'id': 211,
#   'recipe_name': 'Spaghetti Aglio e Olio',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Pasta',
#   'cuisine': 'Italian',
#   'cooking_method': 'Sautéing',
#   'prep_time': '15 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Cook spaghetti and toss with sautéed garlic, red pepper flakes, and olive oil. Garnish with parsley and Parmesan cheese.'},
#  {'id': 212,
#   'recipe_name': 'Baked Ziti',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Pasta',
#   'cuisine': 'Italian',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Mix cooked ziti pasta with marinara sauce and ricotta cheese. Top with mozzarella cheese and bake until bubbly.'},
#  {'id': 213,
#   'recipe_name': 'Vegetable Lasagna',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Vegetables',
#   'cuisine': 'Italian',
#   'cooking_method': 'Baking',
#   'prep_time': '30 minutes',
#   'cook_time': '50 minutes',
#   'instructions': 'Layer lasagna noodles with a mixture of ricotta cheese, spinach, and marinara sauce. Top with mozzarella cheese and bake until bubbly.'},
#  {'id': 214,
#   'recipe_name': 'Chocolate Chip Cookies',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Chocolate Chips',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '10 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Mix flour, sugar, and butter with chocolate chips. Bake until edges are golden and centers are soft.'},
#  {'id': 215,
#   'recipe_name': 'Balsamic Glazed Chicken',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'American',
#   'cooking_method': 'Grilling',
#   'prep_time': '15 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Grill chicken breasts and brush with a glaze made from balsamic vinegar, honey, and Dijon mustard. Serve with steamed vegetables.'},
#  {'id': 217,
#   'recipe_name': 'Chicken Caesar Salad',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'American',
#   'cooking_method': 'Assembling',
#   'prep_time': '10 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'Toss romaine lettuce with Caesar dressing, croutons, and grilled chicken. Top with Parmesan cheese.'},
#  {'id': 218,
#   'recipe_name': 'Vegetable Curry',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Vegetables',
#   'cuisine': 'Indian',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Cook a mix of vegetables in a curry sauce made from onions, garlic, ginger, and coconut milk. Serve with rice or naan.'},
#  {'id': 219,
#   'recipe_name': 'Beef Satay',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Thai',
#   'cooking_method': 'Grilling',
#   'prep_time': '15 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'Skewer marinated beef strips and grill until cooked through. Serve with a peanut dipping sauce.'},
#  {'id': 221,
#   'recipe_name': 'Chocolate Cake',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Chocolate',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Mix flour, cocoa powder, sugar, and eggs. Bake until a toothpick comes out clean. Frost with chocolate ganache if desired.'},
#  {'id': 223,
#   'recipe_name': 'Mango Sticky Rice',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Mango',
#   'cuisine': 'Thai',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Cook sticky rice with coconut milk and sugar. Serve with fresh mango slices and a sprinkle of sesame seeds.'},
#  {'id': 224,
#   'recipe_name': 'Garlic Butter Shrimp',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Shrimp',
#   'cuisine': 'American',
#   'cooking_method': 'Sautéing',
#   'prep_time': '10 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'Sauté shrimp in garlic butter until pink and cooked through. Serve with lemon wedges and chopped parsley.'},
#  {'id': 226,
#   'recipe_name': 'Baked Salmon',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Salmon',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '10 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Season salmon fillets and bake until cooked through. Serve with lemon wedges and a side of steamed vegetables.'},
#  {'id': 228,
#   'recipe_name': 'Pancakes',
#   'type_of_dish': 'Breakfast',
#   'main_ingredient': 'Pancake Mix',
#   'cuisine': 'American',
#   'cooking_method': 'Griddling',
#   'prep_time': '5 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'Mix pancake batter and pour onto a hot griddle. Cook until bubbles form, then flip. Serve with syrup and butter.'},
#  {'id': 230,
#   'recipe_name': 'Potato Gratin',
#   'type_of_dish': 'Side Dish',
#   'main_ingredient': 'Potatoes',
#   'cuisine': 'French',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '50 minutes',
#   'instructions': 'Layer thinly sliced potatoes with cream, cheese, and garlic. Bake until tender and golden brown on top.'},
#  {'id': 231,
#   'recipe_name': 'Grilled Steak',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Steak',
#   'cuisine': 'American',
#   'cooking_method': 'Grilling',
#   'prep_time': '15 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Season steak and grill to desired doneness. Serve with a side of grilled vegetables or a fresh salad.'},
#  {'id': 233,
#   'recipe_name': 'Goulash',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Hungarian',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '45 minutes',
#   'instructions': 'Cook beef with onions, paprika, and tomatoes. Add potatoes and simmer until beef is tender. Serve with crusty bread.'},
#  {'id': 234,
#   'recipe_name': 'Chickpea Salad',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Chickpeas',
#   'cuisine': 'Mediterranean',
#   'cooking_method': 'Assembling',
#   'prep_time': '10 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'Mix chickpeas with diced cucumbers, tomatoes, red onions, and feta cheese. Drizzle with olive oil and lemon juice.'},
#  {'id': 235,
#   'recipe_name': 'Mushroom Risotto',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Rice',
#   'cuisine': 'Italian',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Cook Arborio rice slowly in vegetable broth, adding sautéed mushrooms and Parmesan cheese. Stir frequently until creamy.'},
#  {'id': 236,
#   'recipe_name': 'Beef and Ale Pie',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'British',
#   'cooking_method': 'Baking',
#   'prep_time': '30 minutes',
#   'cook_time': '90 minutes',
#   'instructions': 'Cook beef with onions and ale. Fill a pie crust and bake until crust is golden and filling is thickened.'},
#  {'id': 237,
#   'recipe_name': 'Pasta Primavera',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Pasta',
#   'cuisine': 'Italian',
#   'cooking_method': 'Sautéing',
#   'prep_time': '15 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Cook pasta and toss with a variety of sautéed vegetables and a light olive oil or tomato sauce. Garnish with Parmesan cheese.'},
#  {'id': 239,
#   'recipe_name': 'Avocado Smoothie',
#   'type_of_dish': 'Snack',
#   'main_ingredient': 'Avocado',
#   'cuisine': 'American',
#   'cooking_method': 'Blending',
#   'prep_time': '5 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'Blend avocado with milk or yogurt and a touch of honey until smooth. Serve chilled.'},
#  {'id': 240,
#   'recipe_name': 'Banana Smoothie',
#   'type_of_dish': 'Snack',
#   'main_ingredient': 'Bananas',
#   'cuisine': 'American',
#   'cooking_method': 'Blending',
#   'prep_time': '5 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'Blend bananas with milk and a touch of honey until smooth. Serve chilled.'},
#  {'id': 242,
#   'recipe_name': 'Quinoa Salad',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Quinoa',
#   'cuisine': 'Mediterranean',
#   'cooking_method': 'Assembling',
#   'prep_time': '10 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'Mix cooked quinoa with diced cucumbers, tomatoes, feta cheese, and olives. Drizzle with olive oil and lemon juice.'},
#  {'id': 243,
#   'recipe_name': 'Chicken Tenders',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'American',
#   'cooking_method': 'Frying',
#   'prep_time': '15 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Bread and fry chicken strips until crispy. Serve with dipping sauce or on a salad.'},
#  {'id': 244,
#   'recipe_name': 'Roasted Vegetables',
#   'type_of_dish': 'Side Dish',
#   'main_ingredient': 'Vegetables',
#   'cuisine': 'American',
#   'cooking_method': 'Roasting',
#   'prep_time': '10 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Toss chopped vegetables with olive oil and seasonings. Roast in the oven until tender and caramelized.'},
#  {'id': 245,
#   'recipe_name': 'Chia Seed Pudding',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Chia Seeds',
#   'cuisine': 'American',
#   'cooking_method': 'Chilling',
#   'prep_time': '10 minutes',
#   'cook_time': '4 hours',
#   'instructions': 'Mix chia seeds with milk or almond milk and sweetener. Refrigerate until thickened. Serve with fresh fruit.'},
#  {'id': 246,
#   'recipe_name': 'Sweet Potato Fries',
#   'type_of_dish': 'Side Dish',
#   'main_ingredient': 'Sweet Potatoes',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '10 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Cut sweet potatoes into fries and toss with olive oil and seasonings. Bake until crispy and golden.'},
#  {'id': 247,
#   'recipe_name': 'Chicken and Rice Soup',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'American',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Simmer chicken with rice, vegetables, and broth. Season to taste and serve hot.'},
#  {'id': 248,
#   'recipe_name': 'Lemon Bars',
#   'type_of_dish': 'Dessert',
#   'main_ingredient': 'Lemons',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Mix lemon juice, sugar, and eggs with flour and bake until set. Dust with powdered sugar before serving.'},
#  {'id': 250,
#   'recipe_name': 'Vegetable Frittata',
#   'type_of_dish': 'Breakfast',
#   'main_ingredient': 'Vegetables',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '10 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Mix eggs with sautéed vegetables and cheese. Bake until set and lightly browned. Serve warm.'},
#  {'id': 251,
#   'recipe_name': 'Beef Chili',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'American',
#   'cooking_method': 'Simmering',
#   'prep_time': '15 minutes',
#   'cook_time': '45 minutes',
#   'instructions': 'Cook ground beef with onions, tomatoes, and chili spices. Simmer until thickened. Serve with cornbread or rice.'},
#  {'id': 253,
#   'recipe_name': 'Spicy Tuna Sushi Rolls',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Tuna',
#   'cuisine': 'Japanese',
#   'cooking_method': 'Rolling',
#   'prep_time': '30 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Mix tuna with spicy mayo and roll with sushi rice and nori. Slice into bite-sized pieces and serve with soy sauce and pickled ginger.'},
#  {'id': 255,
#   'recipe_name': 'Baked Macaroni and Cheese',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Pasta',
#   'cuisine': 'American',
#   'cooking_method': 'Baking',
#   'prep_time': '15 minutes',
#   'cook_time': '45 minutes',
#   'instructions': 'Mix cooked macaroni with a cheese sauce made from cheddar, milk, and butter. Bake until bubbly and golden brown.'},
#  {'id': 257,
#   'recipe_name': 'Chicken Tortilla Soup',
#   'type_of_dish': 'Appetizer',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Mexican',
#   'cooking_method': 'Simmering',
#   'prep_time': '10 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Cook chicken with tomatoes, beans, and spices. Top with tortilla strips and garnish with cilantro and lime.'}]

# %% [markdown]
# #### Minisearch

# %%
import minsearch

index = minsearch.Index(
    text_fields=['recipe_name', 'type_of_dish', 'main_ingredient', 'cuisine',
       'cooking_method', 'prep_time', 'cook_time', 'instructions'],
    keyword_fields=['id']
)

# %%
index.fit(documents)

# %%
query = "give me how to cook spaghetti bolognese"

index.search(query=query, num_results=10)
# Out:
# [{'id': 0,
#   'recipe_name': 'Spaghetti Bolognese',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Italian',
#   'cooking_method': 'Simmering',
#   'prep_time': '10 minutes',
#   'cook_time': '40 minutes',
#   'instructions': 'Heat olive oil in a large pan over medium heat. Add finely chopped onions, carrots, and celery. Cook for 5-7 minutes until softened. Add minced beef and cook until browned. Pour in canned tomatoes, beef broth, and Italian herbs. Simmer uncovered for 30-40 minutes. Stir occasionally and season with salt and pepper. Serve over cooked spaghetti and garnish with fresh basil.'},
#  {'id': 211,
#   'recipe_name': 'Spaghetti Aglio e Olio',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Pasta',
#   'cuisine': 'Italian',
#   'cooking_method': 'Sautéing',
#   'prep_time': '15 minutes',
#   'cook_time': '15 minutes',
#   'instructions': 'Cook spaghetti and toss with sautéed garlic, red pepper flakes, and olive oil. Garnish with parsley and Parmesan cheese.'},
#  {'id': 63,
#   'recipe_name': 'Spaghetti Carbonara',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Pasta',
#   'cuisine': 'Italian',
#   'cooking_method': 'Sautéing',
#   'prep_time': '10 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Cook pasta according to package instructions. In a skillet, cook pancetta or bacon until crispy. Whisk eggs and Parmesan cheese together. Toss cooked pasta with bacon and the egg mixture. Serve immediately with extra cheese and black pepper.'},
#  {'id': 15,
#   'recipe_name': 'Chicken Parmesan',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Italian',
#   'cooking_method': 'Baking',
#   'prep_time': '20 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Preheat oven to 200°C (400°F). Pound chicken breasts to an even thickness. Dredge in flour, dip in beaten egg, and coat with breadcrumbs. Fry in olive oil until golden brown. Place chicken in a baking dish, top with marinara sauce and mozzarella cheese. Bake for 20-25 minutes until chicken is cooked through and cheese is melted. Serve with spaghetti.'},
#  {'id': 31,
#   'recipe_name': 'Shrimp Scampi',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Shrimp',
#   'cuisine': 'Italian',
#   'cooking_method': 'Sautéing',
#   'prep_time': '15 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Cook pasta according to package instructions. In a skillet, heat butter and olive oil. Add garlic and cook until fragrant. Add shrimp and cook until pink. Stir in lemon juice, white wine, and parsley. Toss with cooked pasta and serve with lemon wedges.'},
#  {'id': 11,
#   'recipe_name': 'Chicken Alfredo',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Chicken',
#   'cuisine': 'Italian',
#   'cooking_method': 'Sautéing',
#   'prep_time': '15 minutes',
#   'cook_time': '20 minutes',
#   'instructions': 'Cook pasta according to package instructions. In a large skillet, heat butter and sauté garlic until fragrant. Add chicken and cook until no longer pink. Stir in cream and Parmesan cheese, and cook until the sauce thickens. Toss in cooked pasta and season with salt and pepper. Garnish with parsley and serve.'},
#  {'id': 10,
#   'recipe_name': 'Beef Stroganoff',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'Russian',
#   'cooking_method': 'Sautéing',
#   'prep_time': '15 minutes',
#   'cook_time': '30 minutes',
#   'instructions': 'Heat oil in a large pan over medium heat. Add beef strips and cook until browned. Remove beef and set aside. In the same pan, sauté onions and garlic until translucent. Add mushrooms and cook until tender. Stir in flour and cook for 1 minute. Gradually add beef broth and sour cream, stirring until smooth. Return beef to the pan and simmer until cooked through. Serve over egg noodles or rice.'},
#  {'id': 85,
#   'recipe_name': 'Quinoa Salad',
#   'type_of_dish': 'Side Dish',
#   'main_ingredient': 'Quinoa',
#   'cuisine': 'American',
#   'cooking_method': 'Tossing',
#   'prep_time': '15 minutes',
#   'cook_time': '0 minutes',
#   'instructions': 'Cook quinoa according to package instructions. Mix with diced vegetables, feta cheese, and a vinaigrette dressing. Serve chilled or at room temperature.'},
#  {'id': 93,
#   'recipe_name': 'Pancakes',
#   'type_of_dish': 'Breakfast',
#   'main_ingredient': 'Flour',
#   'cuisine': 'American',
#   'cooking_method': 'Grilling',
#   'prep_time': '10 minutes',
#   'cook_time': '10 minutes',
#   'instructions': 'Mix flour, milk, eggs, and baking powder. Pour batter onto a hot griddle and cook until bubbles form. Flip and cook until golden brown. Serve with syrup and butter.'},
#  {'id': 29,
#   'recipe_name': 'Beef Bourguignon',
#   'type_of_dish': 'Main Course',
#   'main_ingredient': 'Beef',
#   'cuisine': 'French',
#   'cooking_method': 'Simmering',
#   'prep_time': '20 minutes',
#   'cook_time': '2 hours',
#   'instructions': 'Preheat oven to 160°C (325°F). In a large pot, brown beef chunks. Remove and set aside. In the same pot, cook onions, carrots, and garlic until softened. Add red wine, beef broth, and tomato paste. Return beef to the pot and add bay leaves. Cover and bake for 1.5-2 hours. Serve with potatoes or crusty bread.'}]

# %% [markdown]
# ### RAG flow

# %%
from openai import OpenAI

client = OpenAI()

# %%
def search(query):
    boost = {}

    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )

    return results

# %%
prompt_template = """
You're a culinary expert. Answer the QUESTION based on the CONTEXT from our recipes database.
Use only the facts from the CONTEXT when answering the QUESTION.

QUESTION: {question}

CONTEXT:
{context}
""".strip()


entry_template = """
recipe_name: {recipe_name}
type_of_dish: {type_of_dish}
main_ingredient: {main_ingredient}
cuisine: {cuisine}
cooking_method: {cooking_method}
prep_time: {prep_time}
cook_time: {cook_time}
instructions: {instructions}
""".strip()

def build_prompt(query, search_results):
    context = ""
    
    for doc in search_results:
        context = context + entry_template.format(**doc) + "\n\n"

    prompt = prompt_template.format(question=query, context=context).strip()
    return prompt

# %%
search_results = search(query)
prompt = build_prompt(query, search_results)

# %%
print(prompt)
# Out:
# You're a culinary expert. Answer the QUESTION based on the CONTEXT from our recipes database.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: give me how to cook spaghetti bolognese
#
# CONTEXT:
# recipe_name: Spaghetti Bolognese
# type_of_dish: Main Course
# main_ingredient: Beef
# cuisine: Italian
# cooking_method: Simmering
# prep_time: 10 minutes
# cook_time: 40 minutes
# instructions: Heat olive oil in a large pan over medium heat. Add finely chopped onions, carrots, and celery. Cook for 5-7 minutes until softened. Add minced beef and cook until browned. Pour in canned tomatoes, beef broth, and Italian herbs. Simmer uncovered for 30-40 minutes. Stir occasionally and season with salt and pepper. Serve over cooked spaghetti and garnish with fresh basil.
#
# recipe_name: Spaghetti Aglio e Olio
# type_of_dish: Main Course
# main_ingredient: Pasta
# cuisine: Italian
# cooking_method: Sautéing
# prep_time: 15 minutes
# cook_time: 15 minutes
# instructions: Cook spaghetti and toss with sautéed garlic, red pepper flakes, and olive oil. Garnish with parsley and Parmesan cheese.
#
# recipe_name: Spaghetti Carbonara
# type_of_dish: Main Course
# main_ingredient: Pasta
# cuisine: Italian
# cooking_method: Sautéing
# prep_time: 10 minutes
# cook_time: 20 minutes
# instructions: Cook pasta according to package instructions. In a skillet, cook pancetta or bacon until crispy. Whisk eggs and Parmesan cheese together. Toss cooked pasta with bacon and the egg mixture. Serve immediately with extra cheese and black pepper.
#
# recipe_name: Chicken Parmesan
# type_of_dish: Main Course
# main_ingredient: Chicken
# cuisine: Italian
# cooking_method: Baking
# prep_time: 20 minutes
# cook_time: 30 minutes
# instructions: Preheat oven to 200°C (400°F). Pound chicken breasts to an even thickness. Dredge in flour, dip in beaten egg, and coat with breadcrumbs. Fry in olive oil until golden brown. Place chicken in a baking dish, top with marinara sauce and mozzarella cheese. Bake for 20-25 minutes until chicken is cooked through and cheese is melted. Serve with spaghetti.
#
# recipe_name: Shrimp Scampi
# type_of_dish: Main Course
# main_ingredient: Shrimp
# cuisine: Italian
# cooking_method: Sautéing
# prep_time: 15 minutes
# cook_time: 20 minutes
# instructions: Cook pasta according to package instructions. In a skillet, heat butter and olive oil. Add garlic and cook until fragrant. Add shrimp and cook until pink. Stir in lemon juice, white wine, and parsley. Toss with cooked pasta and serve with lemon wedges.
#
# recipe_name: Chicken Alfredo
# type_of_dish: Main Course
# main_ingredient: Chicken
# cuisine: Italian
# cooking_method: Sautéing
# prep_time: 15 minutes
# cook_time: 20 minutes
# instructions: Cook pasta according to package instructions. In a large skillet, heat butter and sauté garlic until fragrant. Add chicken and cook until no longer pink. Stir in cream and Parmesan cheese, and cook until the sauce thickens. Toss in cooked pasta and season with salt and pepper. Garnish with parsley and serve.
#
# recipe_name: Beef Stroganoff
# type_of_dish: Main Course
# main_ingredient: Beef
# cuisine: Russian
# cooking_method: Sautéing
# prep_time: 15 minutes
# cook_time: 30 minutes
# instructions: Heat oil in a large pan over medium heat. Add beef strips and cook until browned. Remove beef and set aside. In the same pan, sauté onions and garlic until translucent. Add mushrooms and cook until tender. Stir in flour and cook for 1 minute. Gradually add beef broth and sour cream, stirring until smooth. Return beef to the pan and simmer until cooked through. Serve over egg noodles or rice.
#
# recipe_name: Quinoa Salad
# type_of_dish: Side Dish
# main_ingredient: Quinoa
# cuisine: American
# cooking_method: Tossing
# prep_time: 15 minutes
# cook_time: 0 minutes
# instructions: Cook quinoa according to package instructions. Mix with diced vegetables, feta cheese, and a vinaigrette dressing. Serve chilled or at room temperature.
#
# recipe_name: Pancakes
# type_of_dish: Breakfast
# main_ingredient: Flour
# cuisine: American
# cooking_method: Grilling
# prep_time: 10 minutes
# cook_time: 10 minutes
# instructions: Mix flour, milk, eggs, and baking powder. Pour batter onto a hot griddle and cook until bubbles form. Flip and cook until golden brown. Serve with syrup and butter.
#
# recipe_name: Beef Bourguignon
# type_of_dish: Main Course
# main_ingredient: Beef
# cuisine: French
# cooking_method: Simmering
# prep_time: 20 minutes
# cook_time: 2 hours
# instructions: Preheat oven to 160°C (325°F). In a large pot, brown beef chunks. Remove and set aside. In the same pot, cook onions, carrots, and garlic until softened. Add red wine, beef broth, and tomato paste. Return beef to the pot and add bay leaves. Cover and bake for 1.5-2 hours. Serve with potatoes or crusty bread.

# %%
def llm(prompt, model='gpt-4o-mini'):
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}]
    )
    
    return response.choices[0].message.content

# %%
def rag(query, model='gpt-4o-mini'):
    search_results = search(query)
    prompt = build_prompt(query, search_results)
    #print(prompt)
    answer = llm(prompt, model=model)
    return answer

# %%
question = 'What is the main ingredient of Spaghetti Bolognese? and how to make it?'
answer = rag(question)
print(answer)
# Out:
# The main ingredient of Spaghetti Bolognese is beef.
#
# To make Spaghetti Bolognese, follow these instructions:
#
# 1. Heat olive oil in a large pan over medium heat.
# 2. Add finely chopped onions, carrots, and celery, and cook for 5-7 minutes until softened.
# 3. Add minced beef and cook until browned.
# 4. Pour in canned tomatoes, beef broth, and Italian herbs.
# 5. Simmer uncovered for 30-40 minutes, stirring occasionally, and season with salt and pepper.
# 6. Serve over cooked spaghetti and garnish with fresh basil.

# %% [markdown]
# ### Retrieval evaluation

# %%
df_question = pd.read_csv('../data/ground-truth-retrieval.csv')

# %%
df_question.head()
# Out:
#    id                                           question
# 0   0  What should I do after cooking the onions, car...
# 1   0  How long should I simmer the mixture after add...
# 2   0  What ingredients do I need to season the Bolog...
# 3   0  How long does it take to prepare the ingredien...
# 4   0  What type of pasta is recommended to serve wit...

# %%
ground_truth = df_question.to_dict(orient='records')

# %%
ground_truth[0]
# Out:
# {'id': 0,
#  'question': 'What should I do after cooking the onions, carrots, and celery?'}

# %%
def hit_rate(relevance_total):
    cnt = 0

    for line in relevance_total:
        if True in line:
            cnt = cnt + 1

    return cnt / len(relevance_total)

def mrr(relevance_total):
    total_score = 0.0

    for line in relevance_total:
        for rank in range(len(line)):
            if line[rank] == True:
                total_score = total_score + 1 / (rank + 1)

    return total_score / len(relevance_total)

# %%
def minsearch_search(query):
    boost = {}

    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )

    return results

# %%
from tqdm.auto import tqdm

def evaluate(ground_truth, search_function):
    relevance_total = []
    
    for q in tqdm(ground_truth):
        doc_id = q["id"]
        results = search_function(q)
        relevance = [d["id"] == doc_id for d in results]
        relevance_total.append(relevance)
        
    return {
        'hit_rate': hit_rate(relevance_total),
        'mrr': mrr(relevance_total)
    }

# %%
evaluate(ground_truth, lambda q: minsearch_search(q['question']))
# Out:
#   0%|          | 0/910 [00:00<?, ?it/s]
# {'hit_rate': 0.8626373626373627, 'mrr': 0.7083765044479331}

# %% [markdown]
# ### Finding the best parameters

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
df_validation = df_question[:100]
df_test = df_question[100:]

# %%
gt_val = df_validation.to_dict(orient='records')

# %%
# Mock of the minsearch_search function
def minsearch_search(query, boost=None):
    if boost is None:
        boost = {}
    
    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )
    return results

# %%
# Define the search space using hyperopt's hp module
param_ranges = {
    'recipe_name': hp.uniform('recipe_name', 0.0, 3.0),   # Assuming you have a numerical representation or scores
    'type_of_dish': hp.uniform('type_of_dish', 0.0, 3.0),
    'main_ingredient': hp.uniform('main_ingredient', 0.0, 3.0),
    'cuisine': hp.uniform('cuisine', 0.0, 3.0),
    'cooking_method': hp.uniform('cooking_method', 0.0, 3.0),
    'prep_time': hp.uniform('prep_time', 0.0, 120.0),     # Assuming time is in minutes
    'cook_time': hp.uniform('cook_time', 0.0, 180.0),     # Assuming time is in minutes
    'instructions': hp.uniform('instructions', 0.0, 3.0)  # Assuming you have a numerical score or similarity score
}

# Objective function for optimization
def objective(boost_params):
    def search_function(q):
        return minsearch_search(q['question'], boost_params)

    results = evaluate(gt_val, search_function)
    
    # Assuming MRR is what we're optimizing and we're maximizing it
    return {'loss': -results['mrr'], 'status': STATUS_OK}  # Hyperopt minimizes, so negate the MRR

# %%
# Run hyperopt optimization
trials = Trials()

best = fmin(
    fn=objective, 
    space=param_ranges, 
    algo=tpe.suggest, 
    max_evals=20, 
    trials=trials
)

print("Best parameters found: ", best)
# Out:
#   0%|          | 0/20 [00:00<?, ?trial/s, best loss=?]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:08,  2.25trial/s, best loss: -0.6567500000000002]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  10%|█         | 2/20 [00:00<00:08,  2.24trial/s, best loss: -0.6784722222222223]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  15%|█▌        | 3/20 [00:01<00:07,  2.31trial/s, best loss: -0.6784722222222223]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  20%|██        | 4/20 [00:01<00:06,  2.36trial/s, best loss: -0.6784722222222223]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  25%|██▌       | 5/20 [00:02<00:06,  2.35trial/s, best loss: -0.6784722222222223]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  30%|███       | 6/20 [00:02<00:06,  2.31trial/s, best loss: -0.6784722222222223]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  35%|███▌      | 7/20 [00:03<00:05,  2.33trial/s, best loss: -0.6784722222222223]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  40%|████      | 8/20 [00:03<00:05,  2.33trial/s, best loss: -0.6837063492063493]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  45%|████▌     | 9/20 [00:03<00:04,  2.29trial/s, best loss: -0.6837063492063493]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  50%|█████     | 10/20 [00:04<00:04,  2.31trial/s, best loss: -0.6866944444444445]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  55%|█████▌    | 11/20 [00:04<00:03,  2.28trial/s, best loss: -0.6866944444444445]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  60%|██████    | 12/20 [00:05<00:03,  2.24trial/s, best loss: -0.6866944444444445]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  65%|██████▌   | 13/20 [00:05<00:03,  2.21trial/s, best loss: -0.6866944444444445]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  70%|███████   | 14/20 [00:06<00:02,  2.22trial/s, best loss: -0.6866944444444445]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  75%|███████▌  | 15/20 [00:06<00:02,  2.21trial/s, best loss: -0.6866944444444445]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  80%|████████  | 16/20 [00:07<00:01,  2.16trial/s, best loss: -0.6866944444444445]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  85%|████████▌ | 17/20 [00:07<00:01,  2.23trial/s, best loss: -0.6866944444444445]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  90%|█████████ | 18/20 [00:07<00:00,  2.28trial/s, best loss: -0.6866944444444445]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  95%|█████████▌| 19/20 [00:08<00:00,  2.27trial/s, best loss: -0.6866944444444445]
#   0%|          | 0/100 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:08<00:00,  2.26trial/s, best loss: -0.6866944444444445]
# Best parameters found:  {'cook_time': np.float64(86.54318555259674), 'cooking_method': np.float64(0.039267515269042486), 'cuisine': np.float64(0.14584725698741952), 'instructions': np.float64(2.235829124458284), 'main_ingredient': np.float64(0.7923264133676281), 'prep_time': np.float64(97.16195429708318), 'recipe_name': np.float64(2.290315090834727), 'type_of_dish': np.float64(1.2413235584483393)}

# %%
def minsearch_improved(query):
    boost = {
        'recipe_name': 2.290315090834727,
        'type_of_dish': 1.2413235584483393,
        'main_ingredient': 0.7923264133676281,
        'cuisine': 0.14584725698741952,
        'cooking_method': 0.039267515269042486,
        'prep_time': 97.16195429708318,
        'cook_time': 86.54318555259674,
        'instructions': 2.235829124458284
    }

    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )

    return results

# Assuming you have a ground truth set and the evaluation function
evaluate(ground_truth, lambda q: minsearch_improved(q['question']))
# Out:
#   0%|          | 0/910 [00:00<?, ?it/s]
# {'hit_rate': 0.8681318681318682, 'mrr': 0.7364242107099256}

# %% [markdown]
# ### RAG Evaluation

# %%
prompt2_template = """
You are an expert evaluator for a RAG system.
Your task is to analyze the relevance of the generated answer to the given question.
Based on the relevance of the generated answer, you will classify it
as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".

Here is the data for evaluation:

Question: {question}
Generated Answer: {answer_llm}

Please analyze the content and context of the generated answer in relation to the question
and provide your evaluation in parsable JSON without using code blocks:

{{
  "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
  "Explanation": "[Provide a brief explanation for your evaluation]"
}}
""".strip()

# %%
len(ground_truth)
# Out:
# 910

# %%
record = ground_truth[0]
question = record['question']
answer_llm = rag(question)

# %%
print(answer_llm)
# Out:
# After cooking the onions, carrots, and celery, the next steps will depend on the specific recipe you are following, as the provided context does not include a recipe that specifically instructs on these ingredients being cooked together. However, if you are following a recipe that includes these ingredients (often referred to as a mirepoix), typically you would proceed by adding the next ingredient or liquid as specified in your recipe, such as broth or another main ingredient, to continue cooking the dish.

# %%
prompt = prompt2_template.format(question=question, answer_llm=answer_llm)
print(prompt)
# Out:
# You are an expert evaluator for a RAG system.
# Your task is to analyze the relevance of the generated answer to the given question.
# Based on the relevance of the generated answer, you will classify it
# as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".
#
# Here is the data for evaluation:
#
# Question: What should I do after cooking the onions, carrots, and celery?
# Generated Answer: After cooking the onions, carrots, and celery, the next steps will depend on the specific recipe you are following, as the provided context does not include a recipe that specifically instructs on these ingredients being cooked together. However, if you are following a recipe that includes these ingredients (often referred to as a mirepoix), typically you would proceed by adding the next ingredient or liquid as specified in your recipe, such as broth or another main ingredient, to continue cooking the dish.
#
# Please analyze the content and context of the generated answer in relation to the question
# and provide your evaluation in parsable JSON without using code blocks:
#
# {
#   "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
#   "Explanation": "[Provide a brief explanation for your evaluation]"
# }

# %%
import json

df_sample = df_question.sample(n=10, random_state=1)
sample = df_sample.to_dict(orient='records')
sample
# Out:
# [{'id': 38,
#   'question': 'How long do I need to bake the stuffed bell peppers?'},
#  {'id': 248,
#   'question': 'What cooking method is used for making the Lemon Bars?'},
#  {'id': 22,
#   'question': 'How long does it take to prepare the Sweet and Sour Pork before cooking?'},
#  {'id': 52,
#   'question': 'What cooking method is used for preparing the Chicken Shawarma?'},
#  {'id': 180, 'question': 'What should I serve with the Thai Green Curry?'},
#  {'id': 236,
#   'question': 'What is the main ingredient used in the Beef and Ale Pie recipe?'},
#  {'id': 115,
#   'question': 'What type of cheese do I need to use for this Margherita Pizza recipe?'},
#  {'id': 45,
#   'question': 'What filling ingredients are included in the beef mixture for the empanadas?'},
#  {'id': 248, 'question': 'What should I do before serving the Lemon Bars?'},
#  {'id': 41,
#   'question': 'What is the main cuisine type for this Beef Kebabs recipe?'}]

# %%
evaluations = []

for record in tqdm(ground_truth):
    question = record['question']
    answer_llm = rag(question) 

    prompt = prompt2_template.format(
        question=question,
        answer_llm=answer_llm
    )

    evaluation = llm(prompt)
    evaluation = json.loads(evaluation)

    evaluations.append((record, answer_llm, evaluation))
# Out:
#   0%|          | 0/910 [00:00<?, ?it/s]

# %%
df_eval = pd.DataFrame(evaluations, columns=['record', 'answer', 'evaluation'])

df_eval['id'] = df_eval.record.apply(lambda d: d['id'])
df_eval['question'] = df_eval.record.apply(lambda d: d['question'])

df_eval['relevance'] = df_eval.evaluation.apply(lambda d: d['Relevance'])
df_eval['explanation'] = df_eval.evaluation.apply(lambda d: d['Explanation'])

del df_eval['record']
del df_eval['evaluation']

# %%
df_eval
# Out:
#                                                 answer   id  \
# 0    After cooking the onions, carrots, and celery,...    0
# 1    The context provided does not specify a simmer...    0
# 2    To season the Bolognese sauce, you need salt a...    0
# 3    To prepare the ingredients for the Chicken and...    0
# 4    The context provided does not specify which ty...    0
# ..                                                 ...  ...
# 905  The main ingredient used in the Chicken Tortil...  257
# 906  To prepare the Chicken Tortilla Soup, it takes...  257
# 907  The cooking method used for making the Chicken...  257
# 908  The suggested garnishes for the Chicken Tortil...  257
# 909  The Chicken Tortilla Soup belongs to Mexican c...  257
#
#                                               question        relevance  \
# 0    What should I do after cooking the onions, car...  PARTLY_RELEVANT
# 1    How long should I simmer the mixture after add...  PARTLY_RELEVANT
# 2    What ingredients do I need to season the Bolog...         RELEVANT
# 3    How long does it take to prepare the ingredien...         RELEVANT
# 4    What type of pasta is recommended to serve wit...     NON_RELEVANT
# ..                                                 ...              ...
# 905  What is the main ingredient used in the Chicke...         RELEVANT
# 906  How long does it take to prepare the Chicken T...         RELEVANT
# 907  What cooking method is used for making the Chi...         RELEVANT
# 908  What garnishes are suggested for the Chicken T...         RELEVANT
# 909  Which cuisine does the Chicken Tortilla Soup b...         RELEVANT
#
#                                            explanation
# 0    The generated answer addresses the question by...
# 1    The generated answer addresses the question by...
# 2    The generated answer provides specific ingredi...
# 3    The generated answer directly addresses the qu...
# 4    The generated answer does not address the ques...
# ..                                                 ...
# 905  The generated answer directly addresses the qu...
# 906  The generated answer directly addresses the qu...
# 907  The generated answer directly addresses the qu...
# 908  The generated answer directly addresses the qu...
# 909  The generated answer correctly identifies that...
#
# [910 rows x 5 columns]

# %%
df_eval.relevance.value_counts()
# Out:
# relevance
# RELEVANT           807
# PARTLY_RELEVANT     91
# NON_RELEVANT        12
# Name: count, dtype: int64

# %%
df_eval.relevance.value_counts(normalize=True)
# Out:
# relevance
# RELEVANT           0.886813
# PARTLY_RELEVANT    0.100000
# NON_RELEVANT       0.013187
# Name: proportion, dtype: float64

# %%
df_eval.to_csv('../data/rag-eval-gpt-4o-mini.csv', index=False)

# %%
df_eval[df_eval.relevance == 'NON_RELEVANT']
# Out:
#                                                 answer   id  \
# 4    The context provided does not specify which ty...    0
# 47   The cooking method used to make the sushi roll...    9
# 269  The Macaroni and Cheese should be baked until ...   53
# 362  The cooking method used for cooking the crepes...   73
# 410  The context does not specify a specific durati...   84
# 436  The provided recipes do not include specific i...   89
# 527  The cooking method used for the Greek Salad is...  117
# 561  The CONTEXT does not provide specific informat...  129
# 623  The CONTEXT provided does not specify any ingr...  167
# 629  The context provided does not specify a partic...  168
# 730  The context provided does not contain a recipe...  206
# 878  Chicken and Rice Soup is classified as an Appe...  247
#
#                                               question     relevance  \
# 4    What type of pasta is recommended to serve wit...  NON_RELEVANT
# 47   What cooking method is used to make the sushi ...  NON_RELEVANT
# 269  At what temperature should the Macaroni and Ch...  NON_RELEVANT
# 362  What cooking method is used for cooking the cr...  NON_RELEVANT
# 410  How long should I marinate the salmon in teriy...  NON_RELEVANT
# 436  How long should I sauté the onions, garlic, an...  NON_RELEVANT
# 527   What cooking method is used for the Greek Salad?  NON_RELEVANT
# 561  How long should I bake the French fries to mak...  NON_RELEVANT
# 623  What ingredients are mixed with ricotta cheese...  NON_RELEVANT
# 629  Is there a specific type of olive oil that you...  NON_RELEVANT
# 730  What are the main ingredients in the Chicken S...  NON_RELEVANT
# 878  What type of dish is Chicken and Rice Soup cla...  NON_RELEVANT
#
#                                            explanation
# 4    The generated answer does not address the ques...
# 47   The generated answer incorrectly identifies 'R...
# 269  The generated answer does not provide the spec...
# 362  The generated answer incorrectly states that c...
# 410  The generated answer does not provide any spec...
# 436  The generated answer fails to address the ques...
# 527  The question asks about the cooking method use...
# 561  The generated answer does not provide any info...
# 623  The generated answer does not provide any rele...
# 629  The generated answer does not address the spec...
# 730  The generated answer does not provide any info...
# 878  The generated answer incorrectly classifies Ch...
